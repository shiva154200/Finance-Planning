# %%
import pandas as pd;
import numpy as np;

# %%
df=pd.read_csv("E:\Python\Finance Planning\Finance-Planning\ml-service\datasets\customer_financial_profiles_500.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\shiva\AppData\Local\Temp\ipykernel_17308\149711292.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df=pd.read_csv("E:\Python\Finance Planning\Finance-Planning\ml-service\datasets\customer_financial_profiles_500.csv")

# %%
df
# Out:
#     customer_id  age         occupation  dependents  monthly_income  \
# 0         C0001   23      Bank Employee           1           58700
# 1         C0002   49  Software Engineer           2           60764
# 2         C0003   55         Accountant           1           66749
# 3         C0004   59           Designer           4           83817
# 4         C0005   38           Designer           2           94683
# ..          ...  ...                ...         ...             ...
# 495       C0496   21            Teacher           1           64458
# 496       C0497   41           Designer           4           67438
# 497       C0498   52         Accountant           1           69635
# 498       C0499   46     Business Owner           3          192728
# 499       C0500   53            Teacher           4           57563
#
#      monthly_expenses  monthly_debt_payment  monthly_savings  cash_savings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            500 non-null    object
#  1   age                    500 non-null    int64
#  2   occupation             500 non-null    object
#  3   dependents             500 non-null    int64
#  4   monthly_income         500 non-null    int64
#  5   monthly_expenses       500 non-null    int64
#  6   monthly_debt_payment   500 non-null    int64
#  7   monthly_savings        500 non-null    int64
#  8   cash_savings           500 non-null    int64
#  9   existing_investments   500 non-null    int64
#  10  property_value         500 non-null    int64
#  11  other_assets           500 non-null    int64
#  12  total_assets           500 non-null    int64
#  13  total_liabilities      500 non-null    int64
#  14  net_worth              500 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# customer_id              0
# age                      0
# occupation               0
# dependents               0
# monthly_income           0
# monthly_expenses         0
# monthly_debt_payment     0
# monthly_savings          0
# cash_savings             0
# existing_investments     0
# property_value           0
# other_assets             0
# total_assets             0
# total_liabilities        0
# net_worth                0
# emergency_fund           0
# insurance_coverage       0
# credit_score             0
# risk_tolerance           0
# investment_experience    0
# risk_score               0
# financial_goal           0
# goal_amount              0
# current_goal_savings     0
# goal_gap                 0
# time_horizon_years       0
# preferred_investment     0
# savings_rate             0
# debt_to_income_ratio     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               age  dependents  monthly_income  monthly_expenses  \
# count  500.000000  500.000000      500.000000        500.000000
# mean    40.832000    1.810000    85042.926000      43102.714000
# std     11.747331    1.254211    33890.891864      19194.765222
# min     21.000000    0.000000    25403.000000      10000.000000
# 25%     30.000000    1.000000    60931.250000      29497.500000
# 50%     41.000000    2.000000    76015.000000      38437.500000
# 75%     51.000000    3.000000   101533.500000      54473.750000
# max     60.000000    4.000000   199420.000000     113342.000000
#
#        monthly_debt_payment  monthly_savings  cash_savings  \
# count            500.000000       500.000000  5.000000e+02
# mean           10491.972000     31450.314000  5.986808e+05
# std             7654.155012     16798.086313  3.476162e+05
# min                0.000000         0.000000  8.796400e+04
# 25%             5302.500000     19961.750000  3.375240e+05
# ...

# %%
df.describe(include="object")
# Out:
#        customer_id           occupation risk_tolerance investment_experience  \
# count          500                  500            500                   500
# unique         500                   10              3                     3
# top          C0001  Government Employee       Moderate          Intermediate
# freq             1                   54            249                   231
#
#          financial_goal preferred_investment
# count               500                  500
# unique                7                   10
# top     Wealth Creation            Equity MF
# freq                144                  104

# %%
df.risk_score.max()
# Out:
# np.float64(10.0)

# %%
df.groupby(['age']).risk_score.mean()
# Out:
# age
# 21    6.490000
# 22    5.914286
# 23    6.047059
# 24    7.415789
# 25    6.466667
# 26    6.220000
# 27    5.993333
# 28    5.783333
# 29    6.475000
# 30    6.788889
# 31    5.566667
# 32    5.942857
# 33    5.450000
# 34    4.710000
# 35    6.562500
# 36    5.650000
# 37    5.518182
# 38    6.392857
# 39    6.022222
# 40    6.452941
# 41    5.105556
# 42    6.783333
# 43    6.140000
# 44    5.650000
# 45    5.975000
# 46    6.464706
# 47    6.440000
# 48    5.253846
# 49    5.884615
# 50    6.550000
# 51    5.726667
# 52    6.528571
# 53    6.252632
# 54    5.491667
# 55    6.055556
# 56    6.769231
# 57    6.308333
# 58    5.684615
# 59    5.875000
# 60    6.336842
# Name: risk_score, dtype: float64

# %%
calculated_savings = (
    df["monthly_income"]
    - df["monthly_expenses"]
    - df["monthly_debt_payment"]
)

(df["monthly_savings"] == calculated_savings).all()
# Out:
# np.False_
